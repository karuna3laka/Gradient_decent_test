# %%
import pandas as pd

data_frame=pd.read_csv("test_scores.csv")
data_frame
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.scatter(data_frame.math,data_frame.cs,marker="*",color="green")

# %%
list1=data_frame.math
list2=data_frame.cs

# %%
list1
# Out:
# 0    92
# 1    56
# 2    88
# 3    70
# 4    80
# 5    49
# 6    65
# 7    35
# 8    66
# 9    67
# Name: math, dtype: int64

# %%
list2
# Out:
# 0    98
# 1    68
# 2    81
# 3    80
# 4    83
# 5    52
# 6    66
# 7    30
# 8    68
# 9    73
# Name: cs, dtype: int64

# %%
import numpy as np  #add list into an array

X=np.array(list1)
y=np.array(list2)

# %%
X,y
# Out:
# (array([92, 56, 88, 70, 80, 49, 65, 35, 66, 67], dtype=int64),
#  array([98, 68, 81, 80, 83, 52, 66, 30, 68, 73], dtype=int64))

# %%
def gradient_decent(X,y):
    m_curr=b_curr=0
    iterations=100000
    n=len(x)# you can get len of x or y cuz we need only length array 4 eqation
    learning_rate=0.01
    
    for i in range(iterations):
        #impliment y=mx+c
        y_predicted = m_curr * X + b_curr
        m=-(2/n)*sum(X*(y-y_predicted))
        b=--(2/n)*sum(y-y_predicted)
        m_curr=m_curr-learning_rate*m
        b_curr=b_curr-learning_rate*b
        print(f"m_curr:{m_curr},b_curr:{b_curr},iteration{i}")
        
gradient_decent(X,y)
# Out:
# m_curr:98.918,b_curr:-1.3980000000000001,iteration0
# m_curr:-9165.852512000001,b_curr:129.330488,iteration1
# m_curr:858583.1957921921,b_curr:-12115.059858272001,iteration2
# m_curr:-80415789.14384189,b_curr:1134708.3905229312,iteration3
# m_curr:7531835255.50337,b_curr:-106278093.13583937,iteration4
# m_curr:-705440339104.208,b_curr:9954128244.955946,iteration5
# m_curr:66072352252045.87,b_curr:-932315082234.7649,iteration6
# m_curr:-6188412386021694.0,b_curr:87321701224852.42,iteration7
# m_curr:5.79613810529676e+17,b_curr:-8178650812475637.0,iteration8
# m_curr:-5.42872950929346e+19,b_curr:7.660218270389222e+17,iteration9
# m_curr:5.084610399145189e+21,b_curr:-7.174648398058093e+19,iteration10
# m_curr:-4.762304488893233e+23,b_curr:6.719858079597782e+21,iteration11
# m_curr:4.460429072155747e+25,b_curr:-6.293896244749462e+23,iteration12
# m_curr:-4.177689090257205e+27,b_curr:5.894935498703634e+25,iteration13
# ...
